# %%
import boto3
import os
from botocore.config import Config

def get_aws_client(service_name: str):
    is_local = os.getenv('ENVIRONMENT', 'local') == 'local'
    
    if is_local:
        return boto3.client(
            service_name,
            endpoint_url='http://localhost:4566',
            aws_access_key_id='test',
            aws_secret_access_key='test',
            region_name='us-east-1',
            config=Config(s3={'addressing_style': 'path'})
        )
    return boto3.client(service_name)

# Uso
s3 = get_aws_client('s3')
s3.create_bucket(Bucket='mi-bucket')
s3.put_object(Bucket='mi-bucket', Key='archivo.json', Body='{"test": true}')
# Out:
# {'ResponseMetadata': {'RequestId': '9b3e8705-5487-479d-b354-07f4f7d35208',
#   'HostId': 's9lzHYrFp76ZVxRcpX9+5cjAnEH2ROuNkd2BHfIa6UkFVdtjf5mKR3/eTPFvsiP/XV/VLi31234=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'TwistedWeb/24.3.0',
#    'date': 'Thu, 05 Feb 2026 21:28:13 GMT',
#    'etag': '"efebd898e52c44e3b3514775e5a7c2fa"',
#    'x-amz-checksum-crc32': 'CLyvow==',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'x-amz-server-side-encryption': 'AES256',
#    'x-amz-request-id': '9b3e8705-5487-479d-b354-07f4f7d35208',
#    'x-amz-id-2': 's9lzHYrFp76ZVxRcpX9+5cjAnEH2ROuNkd2BHfIa6UkFVdtjf5mKR3/eTPFvsiP/XV/VLi31234=',
#    'x-localstack': 'true',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"efebd898e52c44e3b3514775e5a7c2fa"',
#  'ChecksumCRC32': 'CLyvow==',
#  'ChecksumType': 'FULL_OBJECT',
#  'ServerSideEncryption': 'AES256'}

# %%
s3.list_buckets()
# Out:
# {'ResponseMetadata': {'RequestId': '25902aa2-a024-4882-993a-69956a049bdc',
#   'HostId': 's9lzHYrFp76ZVxRcpX9+5cjAnEH2ROuNkd2BHfIa6UkFVdtjf5mKR3/eTPFvsiP/XV/VLi31234=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'TwistedWeb/24.3.0',
#    'date': 'Thu, 05 Feb 2026 21:29:27 GMT',
#    'content-type': 'application/xml',
#    'access-control-allow-origin': '*',
#    'access-control-allow-methods': 'HEAD,GET,PUT,POST,DELETE,OPTIONS,PATCH',
#    'access-control-allow-headers': 'authorization,cache-control,content-length,content-md5,content-type,etag,location,x-amz-acl,x-amz-content-sha256,x-amz-date,x-amz-request-id,x-amz-security-token,x-amz-tagging,x-amz-target,x-amz-user-agent,x-amz-version-id,x-amzn-requestid,x-localstack-target,amz-sdk-invocation-id,amz-sdk-request,x-amz-log-type',
#    'access-control-expose-headers': 'etag,x-amz-version-id,x-amz-log-result,x-amz-executed-version,x-amz-function-error',
#    'vary': 'Origin',
#    'content-length': '678',
#    'x-amz-request-id': '25902aa2-a024-4882-993a-69956a049bdc',
#    'x-amz-id-2': 's9lzHYrFp76ZVxRcpX9+5cjAnEH2ROuNkd2BHfIa6UkFVdtjf5mKR3/eTPFvsiP/XV/VLi31234=',
#    'x-localstack': 'true'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'mi-bucket',
#    'CreationDate': datetime.datetime(2026, 2, 5, 21, 28, 12, tzinfo=tzutc()),
#    'BucketRegion': 'us-east-1'},
#   {'Name': 'mi-bucket-uploads',
#    'CreationDate': datetime.datetime(2026, 2, 5, 21, 23, 5, tzinfo=tzutc()),
#    'BucketRegion': 'us-east-1'},
#   {'Name': 'test-bucket',
#    'CreationDate': datetime.datetime(2026, 2, 4, 14, 19, 45, tzinfo=tzutc()),
#    'BucketRegion': 'us-east-1'}],
#  'Owner': {'DisplayName': 'webfile',
#   'ID': '75aa57f09aa0c8caeab4f8c24e99d10f8e7faeebf76c078efc7c6caea54ba06a'}}
